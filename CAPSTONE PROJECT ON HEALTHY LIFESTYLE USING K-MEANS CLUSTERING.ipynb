# %% [markdown]
# # ANALYSIS OF HEALTHY LIFESTYLE ACROSS CITIES

# %% [markdown]
# Health as an indicator of the quality of life of the population Indicators of health and morbidity refer to mental groups of healthy and sick people. This obliges us to approach the characterization of a person's lifestyle not only from biological, but also from medical and social positions. An important quality of health as an element of quality is the level of self-determination of behavior, that is, a responsible attitude to the preservation and occurrence of people in their health. In this sense, health as a real human resource, amateurs can dispose of differently with different results.
#
# The main aim of this is to find relationships between various factors that lead to healthy or unhealthy lifestyle in cities and visualize them. Based on given data set we need to cluster healthy life style city in 2021 into certain group. This data contain different feature and overall 44 healthy lifestyle cities in world. And to perform exploratory data analysis for top 5 healthiest cities as well as unhealthiest cities. And perform k-means clustering to improve statistical analysis

# %% [markdown]
# ![OIP.jpg](attachment:OIP.jpg)

# %% [markdown]
# # Import packages and load the csv file into DataFrame format

# %%
import pandas as pd
file=pd.read_csv("C:/Users/deepika sakthivel/Downloads/Healthy lifestyle across cities.csv")
df=pd.DataFrame(file)
df
# Out:
#                 City  Rank  Sunshine hours(City)  \
# 0          Amsterdam     1                1858.0
# 1             Sydney     2                2636.0
# 2             Vienna     3                1884.0
# 3          Stockholm     4                1821.0
# 4         Copenhagen     5                1630.0
# 5           Helsinki     6                1662.0
# 6            Fukuoka     7                2769.0
# 7             Berlin     8                1626.0
# 8          Barcelona     9                2591.0
# 9          Vancouver    10                1938.0
# 10         Melbourne    11                2363.0
# 11           Beijing    12                2671.0
# 12           Bangkok    13                2624.0
# 13      Buenos Aires    14                2525.0
# 14           Toronto    15                2066.0
# 15            Madrid    16                2769.0
# 16           Jakarta    17                2983.0
# 17             Seoul    18                2066.0
# 18         Frankfurt    19                1662.0
# 19            Geneva    20                   NaN
# 20          Tel Aviv    21                3311.0
# 21          Istanbul    22                2218.0
# 22             Cairo    23                3542.0
# 23            Taipei    24                1405.0
# 24       Los Angeles    25                3254.0
# 25            Mumbai    26                2584.0
# 26            Boston    27                2634.0
# 27            Dublin    28                1453.0
# 28             Tokyo    29                1877.0
# 29           Chicago    30                2508.0
# 30         Hong Kong    31                1836.0
# 31          Shanghai    32                1776.0
# 32          Brussels    33                1546.0
# 33     San Francisco    34                3062.0
# 34             Paris    35                1662.0
# 35         Sao Paulo    36                2003.0
# 36            Zurich    37                1566.0
# 37            London    38                1633.0
# 38      Johannesburg    39                3124.0
# 39             Milan    40                1915.0
# 40  Washington, D.C.    41                2528.0
# 41          New York    42                2535.0
# 42            Moscow    43                1901.0
# 43       Mexico City    44                2555.0
#
#    Cost of a bottle of water(City) Obesity levels(Country)  \
# 0                            £1.92                  20.40%
# 1                            £1.48                  29.00%
# 2                            £1.94                  20.10%
# 3                            £1.72                  20.60%
# 4                            £2.19                  19.70%
# 5                            £1.60                  22.20%
# 6                            £0.78                   4.30%
# 7                            £1.55                  22.30%
# 8                            £1.19                  23.80%
# 9                            £1.08                  29.40%
# 10                           £1.57                  29.00%
# 11                           £0.26                   6.20%
# 12                           £0.22                  10.00%
# 13                           £0.57                  28.30%
# 14                           £1.09                  29.40%
# 15                           £1.30                  23.80%
# 16                           £0.21                   6.90%
# 17                           £0.59                   4.70%
# 18                           £1.95                  22.30%
# 19                           £2.62                  19.50%
# 20                           £1.63                  26.10%
# 21                           £0.15                  32.10%
# 22                           £0.16                  32.00%
# 23                           £0.57                   6.20%
# 24                           £1.52                  36.20%
# 25                           £0.15                   3.90%
# 26                           £1.39                  36.20%
# 27                           £1.40                  25.30%
# 28                           £0.76                   4.30%
# 29                           £1.20                  36.20%
# 30                           £0.75                   6.20%
# 31                           £0.29                   6.20%
# 32                           £2.11                  22.10%
# 33                           £1.60                  36.20%
# 34                           £1.95                  21.60%
# 35                           £0.44                  22.10%
# 36                           £3.20                  19.50%
# 37                           £1.16                  27.80%
# 38                           £0.59                  28.30%
# 39                           £1.15                  19.90%
# 40                           £1.45                  36.20%
# 41                           £1.32                  36.20%
# 42                           £0.41                  23.10%
# 43                           £0.45                  28.90%
#
#     Life expectancy(years) (Country)  Pollution(Index score) (City)  \
# 0                               81.2                          30.93
# 1                               82.1                          26.86
# 2                               81.0                          17.33
# 3                               81.8                          19.63
# 4                               79.8                          21.24
# 5                               80.4                          13.08
# 6                               83.2                            NaN
# 7                               80.6                          39.41
# 8                               82.2                          65.19
# 9                               81.7                          24.26
# 10                              82.1                          25.90
# 11                              75.4                          85.43
# 12                              74.1                          76.64
# 13                              75.9                          52.64
# 14                              81.7                          37.83
# 15                              82.2                          52.68
# 16                              68.5                          84.39
# 17                              81.3                          57.82
# 18                              80.6                          37.78
# 19                              82.6                          27.25
# 20                              81.9                          47.28
# 21                              74.7                          69.49
# 22                              70.7                          91.74
# 23                              75.4                          49.32
# 24                              78.8                          66.07
# 25                              67.3                          82.84
# 26                              78.8                          27.03
# 27                              80.5                          40.07
# 28                              83.2                          42.84
# 29                              78.8                          43.33
# 30                              75.4                          67.46
# 31                              75.4                          77.40
# 32                              80.4                          62.67
# 33                              78.8                          47.36
# 34                              81.8                          65.10
# 35                              73.9                          79.78
# 36                              82.6                          17.31
# 37                              80.4                          58.91
# 38                              56.3                          61.83
# 39                              82.7                          67.19
# 40                              78.8                          39.18
# 41                              78.8                          57.36
# 42                              69.5                          57.63
# 43                              76.4                          82.78
#
#     Annual avg. hours worked  Happiness levels(Country)  \
# 0                     1434.0                       7.44
# 1                     1712.0                       7.22
# 2                     1501.0                       7.29
# 3                     1452.0                       7.35
# 4                     1380.0                       7.64
# 5                     1540.0                       7.80
# 6                     1644.0                       5.87
# 7                     1386.0                       7.07
# 8                     1686.0                       6.40
# 9                     1670.0                       7.23
# 10                    1712.0                       7.22
# 11                       NaN                       5.12
# 12                       NaN                       5.99
# 13                       NaN                       5.97
# 14                    1670.0                       7.23
# 15                    1686.0                       6.40
# 16                       NaN                       5.28
# 17                    1967.0                       5.87
# 18                    1386.0                       7.07
# 19                    1557.0                       7.56
# 20                    1898.0                       7.12
# 21                    1832.0                       5.13
# 22                       NaN                       4.15
# 23                       NaN                       5.12
# 24                    1779.0                       6.94
# 25                       NaN                       3.57
# 26                    1779.0                       6.94
# 27                    1772.0                       7.09
# 28                    1644.0                       5.87
# 29                    1779.0                       6.94
# 30                       NaN                       5.51
# 31                       NaN                       5.12
# 32                    1583.0                       6.86
# 33                    1779.0                       6.94
# 34                    1505.0                       6.66
# 35                       NaN                       6.37
# 36                    1557.0                       7.56
# 37                    1538.0                       7.16
# 38                       NaN                       4.81
# 39                    1718.0                       6.38
# 40                    1779.0                       6.94
# 41                    1779.0                       6.94
# 42                    1965.0                       5.54
# 43                    2137.0                       6.46
#
#     Outdoor activities(City)  Number of take out places(City)  \
# 0                        422                             1048
# 1                        406                             1103
# 2                        132                             1008
# 3                        129                              598
# 4                        154                              523
# 5                        113                              309
# 6                         35                              539
# 7                        254                             1729
# 8                        585                             2344
# 9                        218                              788
# 10                       243                              813
# 11                       223                              261
# 12                       377                             1796
# 13                       246                             1435
# 14                       174                             1656
# 15                       216                             2491
# 16                       114                              833
# 17                       144                              389
# 18                        23                              551
# 19                        44                              444
# 20                       139                              420
# 21                       419                              934
# 22                       323                              250
# 23                       134                              717
# 24                       223                             1439
# 25                       187                             1183
# 26                        88                              588
# 27                       159                              659
# 28                       387                             5802
# 29                       171                             1320
# 30                       277                             1257
# 31                       108                              346
# 32                        55                              988
# 33                       242                             1031
# 34                       331                             4363
# 35                       158                             3355
# 36                        69                              538
# 37                       433                             6417
# 38                       194                              492
# 39                       110                             2396
# 40                        83                              744
# 41                       359                             3081
# 42                       322                             3206
# 43                       192                             1313
#
#    Cost of a monthly gym membership(City)
# 0                                  £34.90
# 1                                  £41.66
# 2                                  £25.74
# 3                                  £37.31
# 4                                  £32.53
# 5                                  £35.23
# 6                                  £55.87
# 7                                  £26.11
# 8                                  £37.80
# 9                                  £31.04
# 10                                 £36.89
# 11                                 £38.62
# 12                                 £50.03
# 13                                 £22.45
# 14                                 £32.64
# 15                                 £34.54
# 16                                 £29.94
# 17                                 £43.03
# 18                                 £39.01
# 19                                 £70.00
# 20                                 £58.31
# 21                                 £16.97
# 22                                 £23.25
# 23                                 £34.76
# 24                                 £32.00
# 25                                 £19.54
# 26                                 £46.27
# 27                                 £37.35
# 28                                 £70.82
# 29                                 £41.14
# 30                                 £57.95
# 31                                 £44.68
# 32                                 £25.34
# 33                                 £65.13
# 34                                 £35.93
# 35                                 £16.07
# 36                                 £73.11
# 37                                 £42.71
# 38                                 £24.28
# 39                                 £53.49
# 40                                 £65.99
# 41                                 £64.66
# 42                                 £31.40
# 43                                 £41.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   City                                    44 non-null     object
#  1   Rank                                    44 non-null     int64
#  2   Sunshine hours(City)                    43 non-null     float64
#  3   Cost of a bottle of water(City)         44 non-null     object
#  4   Obesity levels(Country)                 44 non-null     object
#  5   Life expectancy(years) (Country)        44 non-null     float64
#  6   Pollution(Index score) (City)           43 non-null     float64
#  7   Annual avg. hours worked                33 non-null     float64
#  8   Happiness levels(Country)               44 non-null     float64
#  9   Outdoor activities(City)                44 non-null     int64
#  10  Number of take out places(City)         44 non-null     int64
#  11  Cost of a monthly gym membership(City)  44 non-null     object
# dtypes: float64(5), int64(3), object(4)
# memory usage: 4.2+ KB

# %%
df.shape
# Out:
# (44, 12)

# %%
df.head()
# Out:
#          City  Rank  Sunshine hours(City) Cost of a bottle of water(City)  \
# 0   Amsterdam     1                1858.0                           £1.92
# 1      Sydney     2                2636.0                           £1.48
# 2      Vienna     3                1884.0                           £1.94
# 3   Stockholm     4                1821.0                           £1.72
# 4  Copenhagen     5                1630.0                           £2.19
#
#   Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0                  20.40%                              81.2
# 1                  29.00%                              82.1
# 2                  20.10%                              81.0
# 3                  20.60%                              81.8
# 4                  19.70%                              79.8
#
#    Pollution(Index score) (City)  Annual avg. hours worked  \
# 0                          30.93                    1434.0
# 1                          26.86                    1712.0
# 2                          17.33                    1501.0
# 3                          19.63                    1452.0
# 4                          21.24                    1380.0
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 0                       7.44                       422
# 1                       7.22                       406
# 2                       7.29                       132
# 3                       7.35                       129
# 4                       7.64                       154
#
#    Number of take out places(City) Cost of a monthly gym membership(City)
# 0                             1048                                 £34.90
# 1                             1103                                 £41.66
# 2                             1008                                 £25.74
# 3                              598                                 £37.31
# 4                              523                                 £32.53

# %% [markdown]
# # we need to replace "£" and "%"

# %%
df['Cost of a bottle of water(City)'] = df['Cost of a bottle of water(City)'].replace(to_replace ='£', value = '', regex = True)
df['Obesity levels(Country)'] = df['Obesity levels(Country)'].replace(to_replace ='%', value = '', regex = True)
df['Cost of a monthly gym membership(City)'] = df['Cost of a monthly gym membership(City)'].replace(to_replace ='£', value = '', regex = True)
df['Cost of a monthly gym membership(City)']
# Out:
# 0     34.90
# 1     41.66
# 2     25.74
# 3     37.31
# 4     32.53
# 5     35.23
# 6     55.87
# 7     26.11
# 8     37.80
# 9     31.04
# 10    36.89
# 11    38.62
# 12    50.03
# 13    22.45
# 14    32.64
# 15    34.54
# 16    29.94
# 17    43.03
# 18    39.01
# 19    70.00
# 20    58.31
# 21    16.97
# 22    23.25
# 23    34.76
# 24    32.00
# 25    19.54
# 26    46.27
# 27    37.35
# 28    70.82
# 29    41.14
# 30    57.95
# 31    44.68
# 32    25.34
# 33    65.13
# 34    35.93
# 35    16.07
# 36    73.11
# 37    42.71
# 38    24.28
# 39    53.49
# 40    65.99
# 41    64.66
# 42    31.40
# 43    41.99
# Name: Cost of a monthly gym membership(City), dtype: object

# %% [markdown]
# # Data preprocessing

# %%
df['Sunshine hours(City)']=df['Sunshine hours(City)'].map(float)
df['Cost of a bottle of water(City)']=df['Cost of a bottle of water(City)'].map(float)
df['Obesity levels(Country)']=df['Obesity levels(Country)'].map(float)
df['Pollution(Index score) (City)']=df['Pollution(Index score) (City)'].map(float)
df['Annual avg. hours worked']=df['Annual avg. hours worked'].map(float)
df['Cost of a monthly gym membership(City)']=df['Cost of a monthly gym membership(City)'].map(float)

# %%
df['Annual avg. hours worked'].unique()
# Out:
# array([1434., 1712., 1501., 1452., 1380., 1540., 1644., 1386., 1686.,
#        1670.,   nan, 1967., 1557., 1898., 1832., 1779., 1772., 1583.,
#        1505., 1538., 1718., 1965., 2137.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   City                                    44 non-null     object
#  1   Rank                                    44 non-null     int64
#  2   Sunshine hours(City)                    43 non-null     float64
#  3   Cost of a bottle of water(City)         44 non-null     float64
#  4   Obesity levels(Country)                 44 non-null     float64
#  5   Life expectancy(years) (Country)        44 non-null     float64
#  6   Pollution(Index score) (City)           43 non-null     float64
#  7   Annual avg. hours worked                33 non-null     float64
#  8   Happiness levels(Country)               44 non-null     float64
#  9   Outdoor activities(City)                44 non-null     int64
#  10  Number of take out places(City)         44 non-null     int64
#  11  Cost of a monthly gym membership(City)  44 non-null     float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 4.2+ KB

# %% [markdown]
# # Let us look out missing values

# %%
df.isna().sum()
# Out:
# City                                       0
# Rank                                       0
# Sunshine hours(City)                       1
# Cost of a bottle of water(City)            0
# Obesity levels(Country)                    0
# Life expectancy(years) (Country)           0
# Pollution(Index score) (City)              1
# Annual avg. hours worked                  11
# Happiness levels(Country)                  0
# Outdoor activities(City)                   0
# Number of take out places(City)            0
# Cost of a monthly gym membership(City)     0
# dtype: int64

# %% [markdown]
# # Fill the missing values

# %%
x=df["Sunshine hours(City)"].mean()
df["Sunshine hours(City)"].fillna(x,inplace=True)

# %%
x=df["Pollution(Index score) (City)"].mean()
df["Pollution(Index score) (City)"].fillna(x,inplace=True)

# %%
x=df["Annual avg. hours worked"].mean()
df["Annual avg. hours worked"].fillna(x,inplace=True)

# %%
df.isna().sum()
# Out:
# City                                      0
# Rank                                      0
# Sunshine hours(City)                      0
# Cost of a bottle of water(City)           0
# Obesity levels(Country)                   0
# Life expectancy(years) (Country)          0
# Pollution(Index score) (City)             0
# Annual avg. hours worked                  0
# Happiness levels(Country)                 0
# Outdoor activities(City)                  0
# Number of take out places(City)           0
# Cost of a monthly gym membership(City)    0
# dtype: int64

# %% [markdown]
# # Let us check for duplicates

# %%
df.duplicated().sum()
# THERE IS NO DUPLICATED VALUES IN THE DATASET
# Out:
# 0

# %% [markdown]
# # Let us look at the descriptive statistics of the dataset

# %%
df.describe()
# Out:
#             Rank  Sunshine hours(City)  Cost of a bottle of water(City)  \
# count  44.000000             44.000000                        44.000000
# mean   22.500000           2245.860465                         1.173409
# std    12.845233            560.767190                         0.718642
# min     1.000000           1405.000000                         0.150000
# 25%    11.750000           1809.750000                         0.570000
# 50%    22.500000           2142.000000                         1.195000
# 75%    33.250000           2626.500000                         1.600000
# max    44.000000           3542.000000                         3.200000
#
#        Obesity levels(Country)  Life expectancy(years) (Country)  \
# count                 44.00000                          44.00000
# mean                  21.92500                          78.17500
# std                   10.19567                           5.30437
# min                    3.90000                          56.30000
# 25%                   19.50000                          75.40000
# 50%                   22.30000                          80.40000
# 75%                   29.00000                          81.80000
# max                   36.20000                          83.20000
#
#        Pollution(Index score) (City)  Annual avg. hours worked  \
# count                      44.000000                 44.000000
# mean                       51.122326               1672.909091
# std                        21.600553                154.957363
# min                        13.080000               1380.000000
# 25%                        36.067500               1576.500000
# 50%                        51.881163               1672.909091
# 75%                        66.350000               1773.750000
# max                        91.740000               2137.000000
#
#        Happiness levels(Country)  Outdoor activities(City)  \
# count                  44.000000                 44.000000
# mean                    6.435000                213.977273
# std                     0.991202                127.190297
# min                     3.570000                 23.000000
# 25%                     5.870000                125.250000
# 50%                     6.900000                189.500000
# 75%                     7.175000                288.250000
# max                     7.800000                585.000000
#
#        Number of take out places(City)  Cost of a monthly gym membership(City)
# count                        44.000000                               44.000000
# mean                       1443.113636                               40.420000
# std                        1388.803270                               15.006457
# min                         250.000000                               16.070000
# 25%                         548.000000                               31.310000
# 50%                         998.000000                               37.330000
# 75%                        1674.250000                               47.210000
# max                        6417.000000                               73.110000

# %% [markdown]
# # General exploratory data analysis

# %%
import matplotlib.pyplot as plt
df.corr()
# Out:
#                                             Rank  Sunshine hours(City)  \
# Rank                                    1.000000              0.007937
# Sunshine hours(City)                    0.007937              1.000000
# Cost of a bottle of water(City)        -0.141420             -0.331239
# Obesity levels(Country)                 0.197486              0.281115
# Life expectancy(years) (Country)       -0.320034             -0.353388
# Pollution(Index score) (City)           0.419829              0.383466
# Annual avg. hours worked                0.463708              0.443596
# Happiness levels(Country)              -0.231970             -0.328979
# Outdoor activities(City)               -0.076972              0.126767
# Number of take out places(City)         0.363058             -0.210539
# Cost of a monthly gym membership(City)  0.272521              0.029244
#
#                                         Cost of a bottle of water(City)  \
# Rank                                                          -0.141420
# Sunshine hours(City)                                          -0.331239
# Cost of a bottle of water(City)                                1.000000
# Obesity levels(Country)                                        0.293047
# Life expectancy(years) (Country)                               0.612382
# Pollution(Index score) (City)                                 -0.732659
# Annual avg. hours worked                                      -0.479196
# Happiness levels(Country)                                      0.813159
# Outdoor activities(City)                                      -0.260297
# Number of take out places(City)                               -0.089963
# Cost of a monthly gym membership(City)                         0.356461
#
#                                         Obesity levels(Country)  \
# Rank                                                   0.197486
# Sunshine hours(City)                                   0.281115
# Cost of a bottle of water(City)                        0.293047
# Obesity levels(Country)                                1.000000
# Life expectancy(years) (Country)                       0.091071
# Pollution(Index score) (City)                         -0.246972
# Annual avg. hours worked                               0.193710
# Happiness levels(Country)                              0.446399
# Outdoor activities(City)                               0.150171
# Number of take out places(City)                        0.016833
# Cost of a monthly gym membership(City)                -0.070904
#
#                                         Life expectancy(years) (Country)  \
# Rank                                                           -0.320034
# Sunshine hours(City)                                           -0.353388
# Cost of a bottle of water(City)                                 0.612382
# Obesity levels(Country)                                         0.091071
# Life expectancy(years) (Country)                                1.000000
# Pollution(Index score) (City)                                  -0.552715
# Annual avg. hours worked                                       -0.212952
# Happiness levels(Country)                                       0.724587
# Outdoor activities(City)                                       -0.044864
# Number of take out places(City)                                 0.128163
# Cost of a monthly gym membership(City)                          0.417986
#
#                                         Pollution(Index score) (City)  \
# Rank                                                         0.419829
# Sunshine hours(City)                                         0.383466
# Cost of a bottle of water(City)                             -0.732659
# Obesity levels(Country)                                     -0.246972
# Life expectancy(years) (Country)                            -0.552715
# Pollution(Index score) (City)                                1.000000
# Annual avg. hours worked                                     0.395422
# Happiness levels(Country)                                   -0.762935
# Outdoor activities(City)                                     0.236837
# Number of take out places(City)                              0.186281
# Cost of a monthly gym membership(City)                      -0.241757
#
#                                         Annual avg. hours worked  \
# Rank                                                    0.463708
# Sunshine hours(City)                                    0.443596
# Cost of a bottle of water(City)                        -0.479196
# Obesity levels(Country)                                 0.193710
# Life expectancy(years) (Country)                       -0.212952
# Pollution(Index score) (City)                           0.395422
# Annual avg. hours worked                                1.000000
# Happiness levels(Country)                              -0.290647
# Outdoor activities(City)                                0.078753
# Number of take out places(City)                        -0.033546
# Cost of a monthly gym membership(City)                  0.123009
#
#                                         Happiness levels(Country)  \
# Rank                                                    -0.231970
# Sunshine hours(City)                                    -0.328979
# Cost of a bottle of water(City)                          0.813159
# Obesity levels(Country)                                  0.446399
# Life expectancy(years) (Country)                         0.724587
# Pollution(Index score) (City)                           -0.762935
# Annual avg. hours worked                                -0.290647
# Happiness levels(Country)                                1.000000
# Outdoor activities(City)                                -0.137612
# Number of take out places(City)                          0.033116
# Cost of a monthly gym membership(City)                   0.297425
#
#                                         Outdoor activities(City)  \
# Rank                                                   -0.076972
# Sunshine hours(City)                                    0.126767
# Cost of a bottle of water(City)                        -0.260297
# Obesity levels(Country)                                 0.150171
# Life expectancy(years) (Country)                       -0.044864
# Pollution(Index score) (City)                           0.236837
# Annual avg. hours worked                                0.078753
# Happiness levels(Country)                              -0.137612
# Outdoor activities(City)                                1.000000
# Number of take out places(City)                         0.528200
# Cost of a monthly gym membership(City)                 -0.115400
#
#                                         Number of take out places(City)  \
# Rank                                                           0.363058
# Sunshine hours(City)                                          -0.210539
# Cost of a bottle of water(City)                               -0.089963
# Obesity levels(Country)                                        0.016833
# Life expectancy(years) (Country)                               0.128163
# Pollution(Index score) (City)                                  0.186281
# Annual avg. hours worked                                      -0.033546
# Happiness levels(Country)                                      0.033116
# Outdoor activities(City)                                       0.528200
# Number of take out places(City)                                1.000000
# Cost of a monthly gym membership(City)                         0.092610
#
#                                         Cost of a monthly gym membership(City)
# Rank                                                                  0.272521
# Sunshine hours(City)                                                  0.029244
# Cost of a bottle of water(City)                                       0.356461
# Obesity levels(Country)                                              -0.070904
# Life expectancy(years) (Country)                                      0.417986
# Pollution(Index score) (City)                                        -0.241757
# Annual avg. hours worked                                              0.123009
# Happiness levels(Country)                                             0.297425
# Outdoor activities(City)                                             -0.115400
# Number of take out places(City)                                       0.092610
# Cost of a monthly gym membership(City)                                1.000000

# %%
import seaborn as sns
plt.figure(figsize=(8, 8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
plotting=df.hist(figsize=(12,12),color="red")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(10, 10))
sns.countplot(df["Life expectancy(years) (Country)"])
# Out:
# <AxesSubplot:xlabel='Life expectancy(years) (Country)', ylabel='count'>

# %% [markdown]
# # Relationship between happiness level and life expectancy

# %%
plt.scatter(df["Happiness levels(Country)"],df['Life expectancy(years) (Country)'],c="g",s=70)
plt.xlabel("Happiness levels");
plt.ylabel("Life expectancy");
plt.title("Relation between Happiness levels and Life expectancy")
# Out:
# Text(0.5, 1.0, 'Relation between Happiness levels and Life expectancy')

# %% [markdown]
# This clearly shows that happiness levels leads to the higher levels of expectancy. And clearly shows that all lead healthy life because of happiness level

# %% [markdown]
# # Exploratory analysis of data for the 5 healthiest cities.

# %%
df.columns
# Out:
# Index(['City', 'Rank', 'Sunshine hours(City)',
#        'Cost of a bottle of water(City)', 'Obesity levels(Country)',
#        'Life expectancy(years) (Country)', 'Pollution(Index score) (City)',
#        'Annual avg. hours worked', 'Happiness levels(Country)',
#        'Outdoor activities(City)', 'Number of take out places(City)',
#        'Cost of a monthly gym membership(City)'],
#       dtype='object')

# %%
columns=['Sunshine hours(City)', 'Cost of a bottle of water(City)',
       'Obesity levels(Country)', 'Life expectancy(years) (Country)',
       'Pollution(Index score) (City)', 'Annual avg. hours worked',
       'Happiness levels(Country)', 'Outdoor activities(City)',
       'Number of take out places(City)',
       'Cost of a monthly gym membership(City)']

# %%
import matplotlib.pyplot as plt
for column in columns:
  top10 = df.nlargest(5,column)
  plt.figure(figsize=(10,4))
  plt.bar(top10['City'], top10[column],color='blue',alpha=0.9)
  plt.ylabel(column, fontsize = 10)
  plt.xlabel("Country", fontsize = 10)
  plt.title("Top 5 countries per y", fontsize = 10)

# %% [markdown]
# Now we have analyzed the top 5 healthiest cities based on various categories like - Sunshine hours,Cost of Bottle of water,Obesity levels,Life expectancy,pollution,Annual average hours,Happiness level,Outdoor activities,Number of take out places and Cost of monthly gym membership

# %% [markdown]
# # Exploratory analysis of data for least 5 healthiest cities

# %%
for column in columns:
  top10 = df.nsmallest(5,column)
  plt.figure(figsize=(10,4))
  plt.bar(top10['City'], top10[column],color='green',alpha=0.5)
  plt.ylabel(column, fontsize = 10)
  plt.xlabel("Country", fontsize = 10)
  plt.title("Least 5 countries per y", fontsize = 10)

# %% [markdown]
# # Lets look outliers in data

# %%
import seaborn as sns
i=1
plt.figure(figsize=(15,25))
for feature in columns:
    plt.subplot(6,3,i)
    sns.boxplot(y=df[feature])
    i+=1

# %% [markdown]
# # Let us analyze cities in asia

# %% [markdown]
# Asia - is Earth's largest and most populous continent, located primarily in the Eastern and Northern Hemispheres. It shares the continental landmass of Eurasia with the continent of Europe, and the continental landmass of Afro-Eurasia with Africa and Europe. Asia covers an area of 44,579,000 square kilometres (17,212,000 sq mi), about 30% of Earth's total land area and 8.7% of the Earth's total surface area. The continent, which has long been home to the majority of the human population, was the site of many of the first civilizations. Its 4.7 billion people constitutes roughly 60% of the world's population.

# %% [markdown]
# ![download%20%281%29.jpg](attachment:download%20%281%29.jpg)

# %%
Asia=df.loc[[6,11,12,16,17,23,28,30,31]]
Asia
# Out:
#          City  Rank  Sunshine hours(City)  Cost of a bottle of water(City)  \
# 6     Fukuoka     7                2769.0                             0.78
# 11    Beijing    12                2671.0                             0.26
# 12    Bangkok    13                2624.0                             0.22
# 16    Jakarta    17                2983.0                             0.21
# 17      Seoul    18                2066.0                             0.59
# 23     Taipei    24                1405.0                             0.57
# 28      Tokyo    29                1877.0                             0.76
# 30  Hong Kong    31                1836.0                             0.75
# 31   Shanghai    32                1776.0                             0.29
#
#     Obesity levels(Country)  Life expectancy(years) (Country)  \
# 6                       4.3                              83.2
# 11                      6.2                              75.4
# 12                     10.0                              74.1
# 16                      6.9                              68.5
# 17                      4.7                              81.3
# 23                      6.2                              75.4
# 28                      4.3                              83.2
# 30                      6.2                              75.4
# 31                      6.2                              75.4
#
#     Pollution(Index score) (City)  Annual avg. hours worked  \
# 6                       51.122326               1644.000000
# 11                      85.430000               1672.909091
# 12                      76.640000               1672.909091
# 16                      84.390000               1672.909091
# 17                      57.820000               1967.000000
# 23                      49.320000               1672.909091
# 28                      42.840000               1644.000000
# 30                      67.460000               1672.909091
# 31                      77.400000               1672.909091
#
#     Happiness levels(Country)  Outdoor activities(City)  \
# 6                        5.87                        35
# 11                       5.12                       223
# 12                       5.99                       377
# 16                       5.28                       114
# 17                       5.87                       144
# 23                       5.12                       134
# 28                       5.87                       387
# 30                       5.51                       277
# 31                       5.12                       108
#
#     Number of take out places(City)  Cost of a monthly gym membership(City)
# 6                               539                                   55.87
# 11                              261                                   38.62
# 12                             1796                                   50.03
# 16                              833                                   29.94
# 17                              389                                   43.03
# 23                              717                                   34.76
# 28                             5802                                   70.82
# 30                             1257                                   57.95
# 31                              346                                   44.68

# %%
for column in columns:
  plt.figure(figsize=(20,8))
  plt.bar(Asia['City'], Asia[column],color='blue',alpha=0.2)
  plt.ylabel(column, fontsize = 20)
  plt.xlabel("City", fontsize = 20)
  plt.title("Asian cities", fontsize = 20)

# %% [markdown]
# # Clustering cities

# %%
Healthy = df.groupby('City').mean()
Healthy.head()
# Out:
#            Rank  Sunshine hours(City)  Cost of a bottle of water(City)  \
# City
# Amsterdam   1.0                1858.0                             1.92
# Bangkok    13.0                2624.0                             0.22
# Barcelona   9.0                2591.0                             1.19
# Beijing    12.0                2671.0                             0.26
# Berlin      8.0                1626.0                             1.55
#
#            Obesity levels(Country)  Life expectancy(years) (Country)  \
# City
# Amsterdam                     20.4                              81.2
# Bangkok                       10.0                              74.1
# Barcelona                     23.8                              82.2
# Beijing                        6.2                              75.4
# Berlin                        22.3                              80.6
#
#            Pollution(Index score) (City)  Annual avg. hours worked  \
# City
# Amsterdam                          30.93               1434.000000
# Bangkok                            76.64               1672.909091
# Barcelona                          65.19               1686.000000
# Beijing                            85.43               1672.909091
# Berlin                             39.41               1386.000000
#
#            Happiness levels(Country)  Outdoor activities(City)  \
# City
# Amsterdam                       7.44                     422.0
# Bangkok                         5.99                     377.0
# Barcelona                       6.40                     585.0
# Beijing                         5.12                     223.0
# Berlin                          7.07                     254.0
#
#            Number of take out places(City)  \
# City
# Amsterdam                           1048.0
# Bangkok                             1796.0
# Barcelona                           2344.0
# Beijing                              261.0
# Berlin                              1729.0
#
#            Cost of a monthly gym membership(City)
# City
# Amsterdam                                   34.90
# Bangkok                                     50.03
# Barcelona                                   37.80
# Beijing                                     38.62
# Berlin                                      26.11

# %%
Healthy.head()
# Out:
#            Rank  Sunshine hours(City)  Cost of a bottle of water(City)  \
# City
# Amsterdam   1.0                1858.0                             1.92
# Bangkok    13.0                2624.0                             0.22
# Barcelona   9.0                2591.0                             1.19
# Beijing    12.0                2671.0                             0.26
# Berlin      8.0                1626.0                             1.55
#
#            Obesity levels(Country)  Life expectancy(years) (Country)  \
# City
# Amsterdam                     20.4                              81.2
# Bangkok                       10.0                              74.1
# Barcelona                     23.8                              82.2
# Beijing                        6.2                              75.4
# Berlin                        22.3                              80.6
#
#            Pollution(Index score) (City)  Annual avg. hours worked  \
# City
# Amsterdam                          30.93               1434.000000
# Bangkok                            76.64               1672.909091
# Barcelona                          65.19               1686.000000
# Beijing                            85.43               1672.909091
# Berlin                             39.41               1386.000000
#
#            Happiness levels(Country)  Outdoor activities(City)  \
# City
# Amsterdam                       7.44                     422.0
# Bangkok                         5.99                     377.0
# Barcelona                       6.40                     585.0
# Beijing                         5.12                     223.0
# Berlin                          7.07                     254.0
#
#            Number of take out places(City)  \
# City
# Amsterdam                           1048.0
# Bangkok                             1796.0
# Barcelona                           2344.0
# Beijing                              261.0
# Berlin                              1729.0
#
#            Cost of a monthly gym membership(City)
# City
# Amsterdam                                   34.90
# Bangkok                                     50.03
# Barcelona                                   37.80
# Beijing                                     38.62
# Berlin                                      26.11

# %% [markdown]
# # Drop the column rank

# %%
x=df.drop(['Rank'],axis=1)
x
# Out:
#                 City  Sunshine hours(City)  Cost of a bottle of water(City)  \
# 0          Amsterdam           1858.000000                             1.92
# 1             Sydney           2636.000000                             1.48
# 2             Vienna           1884.000000                             1.94
# 3          Stockholm           1821.000000                             1.72
# 4         Copenhagen           1630.000000                             2.19
# 5           Helsinki           1662.000000                             1.60
# 6            Fukuoka           2769.000000                             0.78
# 7             Berlin           1626.000000                             1.55
# 8          Barcelona           2591.000000                             1.19
# 9          Vancouver           1938.000000                             1.08
# 10         Melbourne           2363.000000                             1.57
# 11           Beijing           2671.000000                             0.26
# 12           Bangkok           2624.000000                             0.22
# 13      Buenos Aires           2525.000000                             0.57
# 14           Toronto           2066.000000                             1.09
# 15            Madrid           2769.000000                             1.30
# 16           Jakarta           2983.000000                             0.21
# 17             Seoul           2066.000000                             0.59
# 18         Frankfurt           1662.000000                             1.95
# 19            Geneva           2245.860465                             2.62
# 20          Tel Aviv           3311.000000                             1.63
# 21          Istanbul           2218.000000                             0.15
# 22             Cairo           3542.000000                             0.16
# 23            Taipei           1405.000000                             0.57
# 24       Los Angeles           3254.000000                             1.52
# 25            Mumbai           2584.000000                             0.15
# 26            Boston           2634.000000                             1.39
# 27            Dublin           1453.000000                             1.40
# 28             Tokyo           1877.000000                             0.76
# 29           Chicago           2508.000000                             1.20
# 30         Hong Kong           1836.000000                             0.75
# 31          Shanghai           1776.000000                             0.29
# 32          Brussels           1546.000000                             2.11
# 33     San Francisco           3062.000000                             1.60
# 34             Paris           1662.000000                             1.95
# 35         Sao Paulo           2003.000000                             0.44
# 36            Zurich           1566.000000                             3.20
# 37            London           1633.000000                             1.16
# 38      Johannesburg           3124.000000                             0.59
# 39             Milan           1915.000000                             1.15
# 40  Washington, D.C.           2528.000000                             1.45
# 41          New York           2535.000000                             1.32
# 42            Moscow           1901.000000                             0.41
# 43       Mexico City           2555.000000                             0.45
#
#     Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0                      20.4                              81.2
# 1                      29.0                              82.1
# 2                      20.1                              81.0
# 3                      20.6                              81.8
# 4                      19.7                              79.8
# 5                      22.2                              80.4
# 6                       4.3                              83.2
# 7                      22.3                              80.6
# 8                      23.8                              82.2
# 9                      29.4                              81.7
# 10                     29.0                              82.1
# 11                      6.2                              75.4
# 12                     10.0                              74.1
# 13                     28.3                              75.9
# 14                     29.4                              81.7
# 15                     23.8                              82.2
# 16                      6.9                              68.5
# 17                      4.7                              81.3
# 18                     22.3                              80.6
# 19                     19.5                              82.6
# 20                     26.1                              81.9
# 21                     32.1                              74.7
# 22                     32.0                              70.7
# 23                      6.2                              75.4
# 24                     36.2                              78.8
# 25                      3.9                              67.3
# 26                     36.2                              78.8
# 27                     25.3                              80.5
# 28                      4.3                              83.2
# 29                     36.2                              78.8
# 30                      6.2                              75.4
# 31                      6.2                              75.4
# 32                     22.1                              80.4
# 33                     36.2                              78.8
# 34                     21.6                              81.8
# 35                     22.1                              73.9
# 36                     19.5                              82.6
# 37                     27.8                              80.4
# 38                     28.3                              56.3
# 39                     19.9                              82.7
# 40                     36.2                              78.8
# 41                     36.2                              78.8
# 42                     23.1                              69.5
# 43                     28.9                              76.4
#
#     Pollution(Index score) (City)  Annual avg. hours worked  \
# 0                       30.930000               1434.000000
# 1                       26.860000               1712.000000
# 2                       17.330000               1501.000000
# 3                       19.630000               1452.000000
# 4                       21.240000               1380.000000
# 5                       13.080000               1540.000000
# 6                       51.122326               1644.000000
# 7                       39.410000               1386.000000
# 8                       65.190000               1686.000000
# 9                       24.260000               1670.000000
# 10                      25.900000               1712.000000
# 11                      85.430000               1672.909091
# 12                      76.640000               1672.909091
# 13                      52.640000               1672.909091
# 14                      37.830000               1670.000000
# 15                      52.680000               1686.000000
# 16                      84.390000               1672.909091
# 17                      57.820000               1967.000000
# 18                      37.780000               1386.000000
# 19                      27.250000               1557.000000
# 20                      47.280000               1898.000000
# 21                      69.490000               1832.000000
# 22                      91.740000               1672.909091
# 23                      49.320000               1672.909091
# 24                      66.070000               1779.000000
# 25                      82.840000               1672.909091
# 26                      27.030000               1779.000000
# 27                      40.070000               1772.000000
# 28                      42.840000               1644.000000
# 29                      43.330000               1779.000000
# 30                      67.460000               1672.909091
# 31                      77.400000               1672.909091
# 32                      62.670000               1583.000000
# 33                      47.360000               1779.000000
# 34                      65.100000               1505.000000
# 35                      79.780000               1672.909091
# 36                      17.310000               1557.000000
# 37                      58.910000               1538.000000
# 38                      61.830000               1672.909091
# 39                      67.190000               1718.000000
# 40                      39.180000               1779.000000
# 41                      57.360000               1779.000000
# 42                      57.630000               1965.000000
# 43                      82.780000               2137.000000
#
#     Happiness levels(Country)  Outdoor activities(City)  \
# 0                        7.44                       422
# 1                        7.22                       406
# 2                        7.29                       132
# 3                        7.35                       129
# 4                        7.64                       154
# 5                        7.80                       113
# 6                        5.87                        35
# 7                        7.07                       254
# 8                        6.40                       585
# 9                        7.23                       218
# 10                       7.22                       243
# 11                       5.12                       223
# 12                       5.99                       377
# 13                       5.97                       246
# 14                       7.23                       174
# 15                       6.40                       216
# 16                       5.28                       114
# 17                       5.87                       144
# 18                       7.07                        23
# 19                       7.56                        44
# 20                       7.12                       139
# 21                       5.13                       419
# 22                       4.15                       323
# 23                       5.12                       134
# 24                       6.94                       223
# 25                       3.57                       187
# 26                       6.94                        88
# 27                       7.09                       159
# 28                       5.87                       387
# 29                       6.94                       171
# 30                       5.51                       277
# 31                       5.12                       108
# 32                       6.86                        55
# 33                       6.94                       242
# 34                       6.66                       331
# 35                       6.37                       158
# 36                       7.56                        69
# 37                       7.16                       433
# 38                       4.81                       194
# 39                       6.38                       110
# 40                       6.94                        83
# 41                       6.94                       359
# 42                       5.54                       322
# 43                       6.46                       192
#
#     Number of take out places(City)  Cost of a monthly gym membership(City)
# 0                              1048                                   34.90
# 1                              1103                                   41.66
# 2                              1008                                   25.74
# 3                               598                                   37.31
# 4                               523                                   32.53
# 5                               309                                   35.23
# 6                               539                                   55.87
# 7                              1729                                   26.11
# 8                              2344                                   37.80
# 9                               788                                   31.04
# 10                              813                                   36.89
# 11                              261                                   38.62
# 12                             1796                                   50.03
# 13                             1435                                   22.45
# 14                             1656                                   32.64
# 15                             2491                                   34.54
# 16                              833                                   29.94
# 17                              389                                   43.03
# 18                              551                                   39.01
# 19                              444                                   70.00
# 20                              420                                   58.31
# 21                              934                                   16.97
# 22                              250                                   23.25
# 23                              717                                   34.76
# 24                             1439                                   32.00
# 25                             1183                                   19.54
# 26                              588                                   46.27
# 27                              659                                   37.35
# 28                             5802                                   70.82
# 29                             1320                                   41.14
# 30                             1257                                   57.95
# 31                              346                                   44.68
# 32                              988                                   25.34
# 33                             1031                                   65.13
# 34                             4363                                   35.93
# 35                             3355                                   16.07
# 36                              538                                   73.11
# 37                             6417                                   42.71
# 38                              492                                   24.28
# 39                             2396                                   53.49
# 40                              744                                   65.99
# 41                             3081                                   64.66
# 42                             3206                                   31.40
# 43                             1313                                   41.99

# %% [markdown]
# # Perform K-Means Clustering algorithm to find different clusters

# %%
import sklearn
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score,silhouette_samples

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
col = Healthy.columns
Healthy_Clust = scaler.fit_transform(Healthy)

# %% [markdown]
# # SilhouetteVisualizer

# %%
import yellowbrick
import matplotlib.pyplot as plt
from yellowbrick.cluster import SilhouetteVisualizer

fig,ax=plt.subplots(4,2,figsize=(15,3))
for i in[2,3,4,5,6,7,8]:
    '''
     Create KMeans instance for different number of clusters
     '''
    km=KMeans(n_clusters=i,init='k-means++',n_init=10,max_iter=100,random_state=42)
    q,mod=divmod(i,2)
    
    #create silhouettevisualization instance with kmeans instance
    #Fit the visualizer
    
    visualizer=SilhouetteVisualizer(km,colors='yellowbrick',ax=ax[q-1][mod])
    visualizer.fit(Healthy_Clust)

# %% [markdown]
# # Elbow graph

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
ssd = []
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]
for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(Healthy_Clust)
    
    ssd.append(kmeans.inertia_)
    
plt.plot(ssd)
plt.grid(linestyle='-',linewidth='1',color='green')
plt.show()

# %% [markdown]
# # Silhouette Score

# %%
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(Healthy_Clust)
    
    cluster_labels = kmeans.labels_
    
    silhouette_avg = silhouette_score(Healthy_Clust, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.23656060232304474
# For n_clusters=3, the silhouette score is 0.2132276901540575
# For n_clusters=4, the silhouette score is 0.22664721065505794
# For n_clusters=5, the silhouette score is 0.20583280427627795
# For n_clusters=6, the silhouette score is 0.21098734711124506
# For n_clusters=7, the silhouette score is 0.24579948176404862
# For n_clusters=8, the silhouette score is 0.21455601779284217

# %%
kmeans = KMeans(n_clusters=5,max_iter=100)
kmeans.fit(Healthy_Clust)
# Out:
# KMeans(max_iter=100, n_clusters=5)

# %%
Healthy['Cluster_ID'] = kmeans.labels_
Healthy.head()
# Out:
#            Rank  Sunshine hours(City)  Cost of a bottle of water(City)  \
# City
# Amsterdam   1.0                1858.0                             1.92
# Bangkok    13.0                2624.0                             0.22
# Barcelona   9.0                2591.0                             1.19
# Beijing    12.0                2671.0                             0.26
# Berlin      8.0                1626.0                             1.55
#
#            Obesity levels(Country)  Life expectancy(years) (Country)  \
# City
# Amsterdam                     20.4                              81.2
# Bangkok                       10.0                              74.1
# Barcelona                     23.8                              82.2
# Beijing                        6.2                              75.4
# Berlin                        22.3                              80.6
#
#            Pollution(Index score) (City)  Annual avg. hours worked  \
# City
# Amsterdam                          30.93               1434.000000
# Bangkok                            76.64               1672.909091
# Barcelona                          65.19               1686.000000
# Beijing                            85.43               1672.909091
# Berlin                             39.41               1386.000000
#
#            Happiness levels(Country)  Outdoor activities(City)  \
# City
# Amsterdam                       7.44                     422.0
# Bangkok                         5.99                     377.0
# Barcelona                       6.40                     585.0
# Beijing                         5.12                     223.0
# Berlin                          7.07                     254.0
#
#            Number of take out places(City)  \
# City
# Amsterdam                           1048.0
# Bangkok                             1796.0
# Barcelona                           2344.0
# Beijing                              261.0
# Berlin                              1729.0
#
#            Cost of a monthly gym membership(City)  Cluster_ID
# City
# Amsterdam                                   34.90           4
# Bangkok                                     50.03           2
# Barcelona                                   37.80           2
# Beijing                                     38.62           1
# Berlin                                      26.11           4

# %% [markdown]
# # Plotting the clusters

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='Happiness levels(Country)',x='Cluster_ID',data=Healthy)
plt.title('Clusters vs Happiness Levels')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='Cost of a bottle of water(City)',x='Cluster_ID',data=Healthy)
plt.title('Clusters vs Cost of a bottle of Water')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='Obesity levels(Country)',x='Cluster_ID',data=Healthy)
plt.title('Clusters vs Obesitiy Levels')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='Annual avg. hours worked',x='Cluster_ID',data=Healthy)
plt.title('Clusters vs Annual average Work Hours')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='Pollution(Index score) (City)',x='Cluster_ID',data=Healthy)
plt.title('Clusters vs Pollution')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='Life expectancy(years) (Country)',x='Cluster_ID',data=Healthy)
plt.title('Clusters vs Life Expectancy')
plt.show()

# %% [markdown]
# # Printing the clusters

# %%
print('Cluster 1:',list(Healthy[Healthy.Cluster_ID==0].index))
# Out:
# Cluster 1: ['Boston', 'Chicago', 'Los Angeles', 'Madrid', 'Mexico City', 'Milan', 'New York', 'San Francisco', 'Tel Aviv', 'Washington, D.C.']

# %%
print('Cluster 2 :',list(Healthy[Healthy.Cluster_ID==1].index))
# Out:
# Cluster 2 : ['Beijing', 'Fukuoka', 'Hong Kong', 'Jakarta', 'Mumbai', 'Seoul', 'Shanghai', 'Taipei']

# %%
print('Cluster 3 :',list(Healthy[Healthy.Cluster_ID==2].index))
# Out:
# Cluster 3 : ['Bangkok', 'Barcelona', 'Buenos Aires', 'Cairo', 'Istanbul', 'Johannesburg', 'Moscow', 'Sao Paulo']

# %%
print('Cluster 4 :',list(Healthy[Healthy.Cluster_ID==3].index))
# Out:
# Cluster 4 : ['London', 'Paris', 'Tokyo']

# %%
print('Cluster 5 :',list(Healthy[Healthy.Cluster_ID==4].index))
# Out:
# Cluster 5 : ['Amsterdam', 'Berlin', 'Brussels', 'Copenhagen', 'Dublin', 'Frankfurt', 'Geneva', 'Helsinki', 'Melbourne', 'Stockholm', 'Sydney', 'Toronto', 'Vancouver', 'Vienna', 'Zurich']

# %% [markdown]
# ### From this project we have successfully clustered cities based on healthy lifestyle using k-means clustering algorithm.Because it consists of different features and continuous data so we use clustering to improve statistical analysis. The number of clusters we have found is five. A healthier lifestyle is consistently associated with a longer life expectancy across various individual risks and irrespective of the presence of multiple long-term medical conditions. The major factor be behind longer life expectancy is happiness. Higher levels of happiness leads to higher life expectancy rates.The main aim is to find relationships between various factors that lead to healthy or unhealthy lifestyle in cities and visualize them.
